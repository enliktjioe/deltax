# %%
import numpy as np

# %%
test = np.zeros(60*180*3).reshape(1,60,180,3)

# %%
test.reshape(60*180*3).
# Out:
# /home/enlik/miniconda3/envs/deltax/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   """Entry point for launching an IPython kernel.
# ...

# %%
"{0}".format(0.32)
# Out:
# '0.32'

# %%
delimit = ","

result = delimit.join(test.reshape(60*180*3))

result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-412799e67c1a> in <module>
#       1 delimit = ","
#       2
# ----> 3 result = delimit.join(test.reshape(60*180*3))
#       4
#       5 result
#
# TypeError: sequence item 0: expected str instance, numpy.float64 found
